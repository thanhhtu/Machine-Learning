# %% [markdown]
# GradientDescent

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 100 # Số lượng mẫu

# Tạo dữ liệu X ngẫu nhiên (mỗi giá trị nằm trong khoảng từ 0 đến 10)
X = np.random.rand(m, 1) * 10  # X là một cột, có kích thước (100, 1)

# Giả định mối quan hệ tuyến tính y = 4 + 3*X + noise
noise = np.random.randn(m, 1) * 2  # Thêm nhiễu Gaussian vào dữ liệu
y = 4 + 3 * X + noise  # y có kích thước (100, 1)

plt.plot(X, y, 'ro')

plt.show()

# %%
def cost(w,b):
    l=0
    for i in range(0, len(X)):
        l+=(w*X[i]+b-y[i])**2
    return l/(2*len(X))

# %%
def gradient(w,b):
    dw=0
    db=0
    for i in range(0, len(X)):
        dw+=(w*X[i]+b-y[i])*X[i]
        db+=(w*X[i]+b-y[i])
    return dw/len(X), db/len(X)

# %%
def train():
    w=0
    b=0
    learning_rate=0.0025
    for i in range(12000):
        dw, db=gradient(w,b)
        w=w-learning_rate*dw
        b=b-learning_rate*db
        if i % 100 == 0:
            print(f"Iteration {i}: w = {w}, b = {b}")
            
    return w, b

# %%
w_opt, b_opt = train()

print("Optimal w:", w_opt)
print("Optimal b:", b_opt)
# Out:
# Iteration 0: w = [0.28466069], b = [0.04646419]
# Iteration 100: w = [3.46869166], b = [0.77625409]
# Iteration 200: w = [3.43564186], b = [0.99442399]
# Iteration 300: w = [3.4039386], b = [1.19946183]
# Iteration 400: w = [3.37412938], b = [1.39224932]
# Iteration 500: w = [3.34610116], b = [1.5735184]
# Iteration 600: w = [3.31974753], b = [1.74395724]
# Iteration 700: w = [3.29496844], b = [1.90421292]
# Iteration 800: w = [3.27166983], b = [2.05489385]
# Iteration 900: w = [3.24976323], b = [2.19657209]
# Iteration 1000: w = [3.22916548], b = [2.32978553]
# Iteration 1100: w = [3.20979837], b = [2.4550399]
# Iteration 1200: w = [3.19158839], b = [2.57281073]
# Iteration 1300: w = [3.17446639], b = [2.68354514]
# Iteration 1400: w = [3.15836738], b = [2.78766354]
# Iteration 1500: w = [3.14323023], b = [2.8855612]
# Iteration 1600: w = [3.12899747], b = [2.97760981]
# Iteration 1700: w = [3.11561507], b = [3.06415881]
# Iteration 1800: w = [3.10303223], b = [3.14553679]
# Iteration 1900: w = [3.09120117], b = [3.2220527]
# Iteration 2000: w = [3.08007698], b = [3.29399705]
# Iteration 2100: w = [3.06961742], b = [3.36164295]
# Iteration 2200: w = [3.05978279], b = [3.42524723]
# Iteration 2300: w = [3.05053574], b = [3.48505137]
# Iteration 2400: w = [3.04184118], b = [3.54128241]
# Iteration 2500: w = [3.03366608], b = [3.59415383]
# Iteration 2600: w = [3.02597942], b = [3.64386635]
# Iteration 2700: w = [3.01875202], b = [3.69060871]
# Iteration 2800: w = [3.01195643], b = [3.73455838]
# Iteration 2900: w = [3.00556685], b = [3.77588219]
# Iteration 3000: w = [2.99955902], b = [3.81473704]
# Iteration 3100: w = [2.99391015], b = [3.85127045]
# Iteration 3200: w = [2.98859878], b = [3.8856211]
# Iteration 3300: w = [2.98360474], b = [3.91791941]
# Iteration 3400: w = [2.97890908], b = [3.94828801]
# Iteration 3500: w = [2.97449397], b = [3.97684218]
# Iteration 3600: w = [2.97034265], b = [4.00369033]
# Iteration 3700: w = [2.96643936], b = [4.0289344]
# Iteration 3800: w = [2.96276928], b = [4.05267021]
# Iteration 3900: w = [2.95931847], b = [4.07498789]
# Iteration 4000: w = [2.95607383], b = [4.09597216]
# Iteration 4100: w = [2.95302306], b = [4.11570269]
# Iteration 4200: w = [2.95015455], b = [4.13425439]
# Iteration 4300: w = [2.94745743], b = [4.15169768]
# Iteration 4400: w = [2.94492146], b = [4.1680988]
# Iteration 4500: w = [2.942537], b = [4.18352]
# Iteration 4600: w = [2.940295], b = [4.19801983]
# Iteration 4700: w = [2.93818696], b = [4.21165335]
# Iteration 4800: w = [2.93620486], b = [4.22447231]
# Iteration 4900: w = [2.93434119], b = [4.23652538]
# Iteration 5000: w = [2.93258887], b = [4.24785831]
# Iteration 5100: w = [2.93094124], b = [4.25851415]
# Iteration 5200: w = [2.92939205], b = [4.26853333]
# Iteration 5300: w = [2.92793542], b = [4.2779539]
# Iteration 5400: w = [2.92656582], b = [4.28681162]
# Iteration 5500: w = [2.92527805], b = [4.29514012]
# Iteration 5600: w = [2.92406722], b = [4.30297102]
# Iteration 5700: w = [2.92292873], b = [4.31033405]
# Iteration 5800: w = [2.92185826], b = [4.31725716]
# Iteration 5900: w = [2.92085175], b = [4.32376664]
# Iteration 6000: w = [2.91990538], b = [4.3298872]
# Iteration 6100: w = [2.91901555], b = [4.33564207]
# Iteration 6200: w = [2.91817888], b = [4.34105312]
# Iteration 6300: w = [2.9173922], b = [4.34614086]
# Iteration 6400: w = [2.91665252], b = [4.35092464]
# Iteration 6500: w = [2.91595704], b = [4.3554226]
# Iteration 6600: w = [2.91530311], b = [4.35965182]
# Iteration 6700: w = [2.91468825], b = [4.36362835]
# Iteration 6800: w = [2.91411012], b = [4.36736731]
# Iteration 6900: w = [2.91356654], b = [4.37088287]
# Iteration 7000: w = [2.91305543], b = [4.37418839]
# Iteration 7100: w = [2.91257486], b = [4.37729642]
# Iteration 7200: w = [2.91212301], b = [4.38021875]
# Iteration 7300: w = [2.91169815], b = [4.38296648]
# Iteration 7400: w = [2.91129867], b = [4.38555004]
# Iteration 7500: w = [2.91092306], b = [4.38797925]
# Iteration 7600: w = [2.91056989], b = [4.39026331]
# Iteration 7700: w = [2.91023783], b = [4.39241092]
# Iteration 7800: w = [2.9099256], b = [4.39443021]
# Iteration 7900: w = [2.90963203], b = [4.39632885]
# Iteration 8000: w = [2.90935599], b = [4.39811406]
# Iteration 8100: w = [2.90909645], b = [4.3997926]
# Iteration 8200: w = [2.90885242], b = [4.40137086]
# Iteration 8300: w = [2.90862297], b = [4.40285482]
# Iteration 8400: w = [2.90840722], b = [4.40425012]
# Iteration 8500: w = [2.90820437], b = [4.40556206]
# Iteration 8600: w = [2.90801363], b = [4.40679561]
# Iteration 8700: w = [2.90783429], b = [4.40795546]
# Iteration 8800: w = [2.90766567], b = [4.40904602]
# Iteration 8900: w = [2.90750712], b = [4.41007141]
# Iteration 9000: w = [2.90735804], b = [4.41103555]
# Iteration 9100: w = [2.90721787], b = [4.41194208]
# Iteration 9200: w = [2.90708608], b = [4.41279444]
# Iteration 9300: w = [2.90696216], b = [4.41359589]
# Iteration 9400: w = [2.90684564], b = [4.41434944]
# Iteration 9500: w = [2.90673609], b = [4.41505798]
# Iteration 9600: w = [2.90663308], b = [4.41572418]
# Iteration 9700: w = [2.90653622], b = [4.41635058]
# Iteration 9800: w = [2.90644515], b = [4.41693955]
# Iteration 9900: w = [2.90635953], b = [4.41749334]
# Iteration 10000: w = [2.90627902], b = [4.41801404]
# Iteration 10100: w = [2.90620331], b = [4.41850362]
# Iteration 10200: w = [2.90613214], b = [4.41896396]
# Iteration 10300: w = [2.90606521], b = [4.41939679]
# Iteration 10400: w = [2.90600228], b = [4.41980376]
# Iteration 10500: w = [2.90594312], b = [4.42018642]
# Iteration 10600: w = [2.90588748], b = [4.42054622]
# Iteration 10700: w = [2.90583518], b = [4.42088451]
# Iteration 10800: w = [2.90578599], b = [4.4212026]
# Iteration 10900: w = [2.90573975], b = [4.42150168]
# Iteration 11000: w = [2.90569627], b = [4.42178289]
# Iteration 11100: w = [2.90565538], b = [4.4220473]
# Iteration 11200: w = [2.90561694], b = [4.42229592]
# Iteration 11300: w = [2.9055808], b = [4.42252968]
# Iteration 11400: w = [2.90554681], b = [4.42274947]
# Iteration 11500: w = [2.90551486], b = [4.42295613]
# Iteration 11600: w = [2.90548481], b = [4.42315044]
# Iteration 11700: w = [2.90545656], b = [4.42333315]
# Iteration 11800: w = [2.90543], b = [4.42350494]
# Iteration 11900: w = [2.90540502], b = [4.42366646]
# Optimal w: [2.90538177]
# Optimal b: [4.42381686]

# %%
x_test = 10
y_pred = w_opt * x_test + b_opt
print(y_pred)
# Out:
# [33.47763456]

# %%
plt.plot(X, y, 'ro')
plt.plot([0, 10], [b_opt, w_opt*10+b_opt], color="blue", label="Đường hồi quy tuyến tính")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Implement Linear Regression theo OOP-style

# %%
class LinearRegression:
    def __init__(self,w=0,b=0):
        self.w = w
        self.b = b
    
    def cost(self, X, y):
        l=0
        for i in range(0, len(X)):
            l+=(self.w*X[i]+self.b-y[i])**2
        return l/(2*len(X))
    
    def gradient(self, X, y):
        dw=0
        db=0
        for i in range(0, len(X)):
            dw+=(self.w*X[i]+self.b-y[i])*X[i]
            db+=(self.w*X[i]+self.b-y[i])
        return dw/len(X), db/len(X)
    
    def train(self,X,y, learning_rate=0.002):
        for i in range(12000):
            dw, db=self.gradient(X, y)
            self.w=self.w-learning_rate*dw
            self.b=self.b-learning_rate*db
            if i % 100 == 0:
                print(f"Iteration {i}: w = {self.w}, b = {self.b}")
        return self.w, self.b
    
    def predict(self, x):
        return self.w*x+self.b
    
    def plot(self, X, y):
        plt.plot(X, y, 'ro')
        plt.plot([0, 10], [self.b, self.w*10+self.b], color="blue", label="Đường hồi quy tuyến tính")
        plt.xlabel("X")
        plt.ylabel("y")
        plt.show()

model = LinearRegression()
model.train(X,y)
model.plot(X, y)
# Out:
# Iteration 0: w = [0.22772855], b = [0.03717135]
# Iteration 100: w = [3.47249686], b = [0.73003414]
# Iteration 200: w = [3.44894605], b = [0.90835043]
# Iteration 300: w = [3.42279432], b = [1.07751474]
# Iteration 400: w = [3.39789567], b = [1.23854374]
# Iteration 500: w = [3.37419432], b = [1.39182932]
# Iteration 600: w = [3.3516327], b = [1.53774383]
# Iteration 700: w = [3.330156], b = [1.67664174]
# Iteration 800: w = [3.30971205], b = [1.80886046]
# Iteration 900: w = [3.2902512], b = [1.93472115]
# Iteration 1000: w = [3.27172616], b = [2.05452957]
# Iteration 1100: w = [3.25409193], b = [2.16857675]
# Iteration 1200: w = [3.23730569], b = [2.27713973]
# Iteration 1300: w = [3.22132664], b = [2.38048223]
# Iteration 1400: w = [3.20611598], b = [2.47885528]
# Iteration 1500: w = [3.19163676], b = [2.57249787]
# Iteration 1600: w = [3.17785381], b = [2.66163745]
# Iteration 1700: w = [3.16473363], b = [2.74649056]
# Iteration 1800: w = [3.15224437], b = [2.82726334]
# Iteration 1900: w = [3.14035568], b = [2.90415198]
# Iteration 2000: w = [3.12903868], b = [2.97734328]
# Iteration 2100: w = [3.11826588], b = [3.04701501]
# Iteration 2200: w = [3.10801112], b = [3.11333643]
# Iteration 2300: w = [3.09824948], b = [3.17646865]
# Iteration 2400: w = [3.08895725], b = [3.23656502]
# Iteration 2500: w = [3.08011185], b = [3.29377154]
# Iteration 2600: w = [3.0716918], b = [3.34822715]
# Iteration 2700: w = [3.06367665], b = [3.40006415]
# Iteration 2800: w = [3.05604693], b = [3.44940846]
# Iteration 2900: w = [3.04878409], b = [3.49637995]
# Iteration 3000: w = [3.04187051], b = [3.54109271]
# Iteration 3100: w = [3.03528938], b = [3.58365537]
# Iteration 3200: w = [3.02902472], b = [3.62417131]
# Iteration 3300: w = [3.0230613], b = [3.66273895]
# Iteration 3400: w = [3.01738465], b = [3.69945199]
# Iteration 3500: w = [3.01198097], b = [3.73439961]
# Iteration 3600: w = [3.00683714], b = [3.76766669]
# Iteration 3700: w = [3.00194067], b = [3.79933406]
# Iteration 3800: w = [2.99727965], b = [3.82947864]
# Iteration 3900: w = [2.99284276], b = [3.85817365]
# Iteration 4000: w = [2.98861923], b = [3.8854888]
# Iteration 4100: w = [2.9845988], b = [3.91149044]
# Iteration 4200: w = [2.9807717], b = [3.93624174]
# Iteration 4300: w = [2.97712864], b = [3.95980282]
# Iteration 4400: w = [2.97366075], b = [3.98223092]
# Iteration 4500: w = [2.97035963], b = [4.00358051]
# Iteration 4600: w = [2.96721725], b = [4.02390347]
# Iteration 4700: w = [2.96422598], b = [4.04324915]
# Iteration 4800: w = [2.96137855], b = [4.06166455]
# Iteration 4900: w = [2.95866805], b = [4.07919441]
# Iteration 5000: w = [2.95608788], b = [4.09588131]
# Iteration 5100: w = [2.95363179], b = [4.11176579]
# Iteration 5200: w = [2.9512938], b = [4.12688643]
# Iteration 5300: w = [2.94906824], b = [4.14127995]
# Iteration 5400: w = [2.94694971], b = [4.15498134]
# Iteration 5500: w = [2.94493304], b = [4.16802387]
# Iteration 5600: w = [2.94301335], b = [4.18043922]
# Iteration 5700: w = [2.94118598], b = [4.19225755]
# Iteration 5800: w = [2.93944647], b = [4.20350757]
# Iteration 5900: w = [2.93779062], b = [4.21421661]
# Iteration 6000: w = [2.93621439], b = [4.22441068]
# Iteration 6100: w = [2.93471396], b = [4.23411455]
# Iteration 6200: w = [2.93328567], b = [4.24335179]
# Iteration 6300: w = [2.93192607], b = [4.25214484]
# Iteration 6400: w = [2.93063185], b = [4.26051505]
# Iteration 6500: w = [2.92939987], b = [4.26848277]
# Iteration 6600: w = [2.92822712], b = [4.27606734]
# Iteration 6700: w = [2.92711078], b = [4.28328719]
# Iteration 6800: w = [2.92604811], b = [4.29015986]
# Iteration 6900: w = [2.92503654], b = [4.29670204]
# Iteration 7000: w = [2.92407362], b = [4.30292963]
# Iteration 7100: w = [2.923157], b = [4.30885775]
# Iteration 7200: w = [2.92228446], b = [4.3145008]
# Iteration 7300: w = [2.92145387], b = [4.3198725]
# Iteration 7400: w = [2.92066323], b = [4.32498588]
# Iteration 7500: w = [2.91991061], b = [4.32985338]
# Iteration 7600: w = [2.91919418], b = [4.33448682]
# Iteration 7700: w = [2.9185122], b = [4.33889745]
# Iteration 7800: w = [2.91786301], b = [4.34309598]
# Iteration 7900: w = [2.91724504], b = [4.34709262]
# Iteration 8000: w = [2.91665679], b = [4.35089707]
# Iteration 8100: w = [2.91609682], b = [4.35451857]
# Iteration 8200: w = [2.91556379], b = [4.35796593]
# Iteration 8300: w = [2.91505638], b = [4.36124751]
# Iteration 8400: w = [2.91457337], b = [4.3643713]
# Iteration 8500: w = [2.91411359], b = [4.36734486]
# Iteration 8600: w = [2.91367592], b = [4.37017544]
# Iteration 8700: w = [2.9132593], b = [4.37286991]
# Iteration 8800: w = [2.91286271], b = [4.3754348]
# Iteration 8900: w = [2.91248519], b = [4.37787636]
# Iteration 9000: w = [2.91212583], b = [4.38020051]
# Iteration 9100: w = [2.91178374], b = [4.38241289]
# Iteration 9200: w = [2.91145811], b = [4.38451889]
# Iteration 9300: w = [2.91114813], b = [4.38652362]
# Iteration 9400: w = [2.91085306], b = [4.38843195]
# Iteration 9500: w = [2.91057218], b = [4.39024851]
# Iteration 9600: w = [2.91030481], b = [4.39197772]
# Iteration 9700: w = [2.91005029], b = [4.39362378]
# Iteration 9800: w = [2.90980801], b = [4.39519068]
# Iteration 9900: w = [2.90957739], b = [4.39668223]
# Iteration 10000: w = [2.90935785], b = [4.39810206]
# Iteration 10100: w = [2.90914887], b = [4.39945361]
# Iteration 10200: w = [2.90894994], b = [4.40074018]
# Iteration 10300: w = [2.90876057], b = [4.40196487]
# Iteration 10400: w = [2.90858031], b = [4.40313067]
# Iteration 10500: w = [2.90840872], b = [4.40424041]
# Iteration 10600: w = [2.90824538], b = [4.40529679]
# Iteration 10700: w = [2.9080899], b = [4.40630237]
# Iteration 10800: w = [2.90794189], b = [4.4072596]
# Iteration 10900: w = [2.907801], b = [4.40817079]
# Iteration 11000: w = [2.90766688], b = [4.40903817]
# Iteration 11100: w = [2.90753922], b = [4.40986384]
# Iteration 11200: w = [2.90741769], b = [4.4106498]
# Iteration 11300: w = [2.90730201], b = [4.41139797]
# Iteration 11400: w = [2.90719189], b = [4.41211016]
# Iteration 11500: w = [2.90708706], b = [4.41278811]
# Iteration 11600: w = [2.90698728], b = [4.41343345]
# Iteration 11700: w = [2.90689229], b = [4.41404776]
# Iteration 11800: w = [2.90680187], b = [4.41463253]
# Iteration 11900: w = [2.9067158], b = [4.41518918]
